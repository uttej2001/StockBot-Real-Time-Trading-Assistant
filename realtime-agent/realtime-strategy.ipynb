# %%
from sklearn.preprocessing import MinMaxScaler
import os
import numpy as np
import pandas as pd
import time
import random

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def softmax(z):
    assert len(z.shape) == 2
    s = np.max(z, axis=1)
    s = s[:, np.newaxis]
    e_x = np.exp(z - s)
    div = np.sum(e_x, axis=1)
    div = div[:, np.newaxis]
    return e_x / div

# %%
df = pd.read_csv('FB.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-23  182.500000  186.910004  182.179993  186.899994  186.899994
# 1  2018-05-24  185.880005  186.800003  185.029999  185.929993  185.929993
# 2  2018-05-25  186.020004  186.330002  184.449997  184.919998  184.919998
# 3  2018-05-29  184.339996  186.809998  183.710007  185.740005  185.740005
# 4  2018-05-30  186.539993  188.000000  185.250000  187.669998  187.669998
#
#      Volume
# 0  16628100
# 1  12354700
# 2  10965100
# 3  16398900
# 4  13736900

# %%
parameters = [df['Close'].tolist(), df['Volume'].tolist()]

# %%
def get_state(parameters, t, window_size = 20):
    outside = []
    d = t - window_size + 1
    for parameter in parameters:
        block = (
            parameter[d : t + 1]
            if d >= 0
            else -d * [parameter[0]] + parameter[0 : t + 1]
        )
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        for i in range(1, window_size, 1):
            res.append(block[i] - block[0])
        outside.append(res)
    return np.array(outside).reshape((1, -1))

# %% [markdown]
# Our output size from `get_state` is 38. Here, we only use `Close` and `Volume` parameters.
#
# Here we added another parameters, my `inventory` size, mean of `inventory` and `capital`.
#
# Let say for an example,
# ```
# inventory_size = 1
# mean_inventory = 0.5
# capital = 2
# last_state = 0
# ```
#
# We have 3 actions,
#
# 1. `0` for do nothing.
# 2. `1` for buy.
# 3. `2` for sell.

# %%
inventory_size = 1
mean_inventory = 0.5
capital = 2
concat_parameters = np.concatenate([get_state(parameters, 20), [[inventory_size, 
                                                                mean_inventory,
                                                                capital]]], axis = 1)

# %%
input_size = concat_parameters.shape[1]
input_size
# Out:
# 79

# %%
class Strategy:
    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights
    
    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')
        
class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.rand(input_size, layer_size)
            * np.sqrt(1 / (input_size + layer_size)),
            np.random.rand(layer_size, output_size)
            * np.sqrt(1 / (layer_size + output_size)),
            np.zeros((1, layer_size)),
            np.zeros((1, output_size)),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-2]
        decision = np.dot(feed, self.weights[1]) + self.weights[-1]
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, timeseries, skip, initial_money, real_trend, minmax):
        self.model = model
        self.timeseries = timeseries
        self.skip = skip
        self.real_trend = real_trend
        self.initial_money = initial_money
        self.es = Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )
        self.minmax = minmax
        self._initiate()

    def _initiate(self):
        # i assume first index is the close value
        self.trend = self.timeseries[0]
        self._mean = np.mean(self.trend)
        self._std = np.std(self.trend)
        self._inventory = []
        self._capital = self.initial_money
        self._queue = []
        self._scaled_capital = self.minmax.transform([[self._capital, 2]])[0, 0]

    def reset_capital(self, capital):
        if capital:
            self._capital = capital
        self._scaled_capital = self.minmax.transform([[self._capital, 2]])[0, 0]
        self._queue = []
        self._inventory = []

    def trade(self, data):
        """
        you need to make sure the data is [close, volume]
        """
        scaled_data = self.minmax.transform([data])[0]
        real_close = data[0]
        close = scaled_data[0]
        if len(self._queue) >= window_size:
            self._queue.pop(0)
        self._queue.append(scaled_data)
        if len(self._queue) < window_size:
            return {
                'status': 'data not enough to trade',
                'action': 'fail',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }
        state = self.get_state(
            window_size - 1,
            self._inventory,
            self._scaled_capital,
            timeseries = np.array(self._queue).T.tolist(),
        )
        action, prob = self.act_softmax(state)
        print(prob)
        if action == 1 and self._scaled_capital >= close:
            self._inventory.append(close)
            self._scaled_capital -= close
            self._capital -= real_close
            return {
                'status': 'buy 1 unit, cost %f' % (real_close),
                'action': 'buy',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }
        elif action == 2 and len(self._inventory):
            bought_price = self._inventory.pop(0)
            self._scaled_capital += close
            self._capital += real_close
            scaled_bought_price = self.minmax.inverse_transform(
                [[bought_price, 2]]
            )[0, 0]
            try:
                invest = (
                    (real_close - scaled_bought_price) / scaled_bought_price
                ) * 100
            except:
                invest = 0
            return {
                'status': 'sell 1 unit, price %f' % (real_close),
                'investment': invest,
                'gain': real_close - scaled_bought_price,
                'balance': self._capital,
                'action': 'sell',
                'timestamp': str(datetime.now()),
            }
        else:
            return {
                'status': 'do nothing',
                'action': 'nothing',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }

    def change_data(self, timeseries, skip, initial_money, real_trend, minmax):
        self.timeseries = timeseries
        self.skip = skip
        self.initial_money = initial_money
        self.real_trend = real_trend
        self.minmax = minmax
        self._initiate()

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))

        return np.argmax(decision[0])

    def act_softmax(self, sequence):
        decision = self.model.predict(np.array(sequence))

        return np.argmax(decision[0]), softmax(decision)[0]

    def get_state(self, t, inventory, capital, timeseries):
        state = get_state(timeseries, t)
        len_inventory = len(inventory)
        if len_inventory:
            mean_inventory = np.mean(inventory)
        else:
            mean_inventory = 0
        z_inventory = (mean_inventory - self._mean) / self._std
        z_capital = (capital - self._mean) / self._std
        concat_parameters = np.concatenate(
            [state, [[len_inventory, z_inventory, z_capital]]], axis = 1
        )
        return concat_parameters

    def get_reward(self, weights):
        initial_money = self._scaled_capital
        starting_money = initial_money
        invests = []
        self.model.weights = weights
        inventory = []
        state = self.get_state(0, inventory, starting_money, self.timeseries)

        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= self.trend[t]

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]
                invest = ((self.trend[t] - bought_price) / bought_price) * 100
                invests.append(invest)

            state = self.get_state(
                t + 1, inventory, starting_money, self.timeseries
            )
        invests = np.mean(invests)
        if np.isnan(invests):
            invests = 0
        score = (starting_money - initial_money) / initial_money * 100
        return invests * 0.7 + score * 0.3

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self._scaled_capital
        starting_money = initial_money

        real_initial_money = self.initial_money
        real_starting_money = self.initial_money
        inventory = []
        real_inventory = []
        state = self.get_state(0, inventory, starting_money, self.timeseries)
        states_sell = []
        states_buy = []

        for t in range(0, len(self.trend) - 1, self.skip):
            action, prob = self.act_softmax(state)
            print(t, prob)

            if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - 1 - window_size):
                inventory.append(self.trend[t])
                real_inventory.append(self.real_trend[t])
                real_starting_money -= self.real_trend[t]
                starting_money -= self.trend[t]
                states_buy.append(t)
                print(
                    'day %d: buy 1 unit at price %f, total balance %f'
                    % (t, self.real_trend[t], real_starting_money)
                )

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                real_bought_price = real_inventory.pop(0)
                starting_money += self.trend[t]
                real_starting_money += self.real_trend[t]
                states_sell.append(t)
                try:
                    invest = (
                        (self.real_trend[t] - real_bought_price)
                        / real_bought_price
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.real_trend[t], invest, real_starting_money)
                )
            state = self.get_state(
                t + 1, inventory, starting_money, self.timeseries
            )

        invest = (
            (real_starting_money - real_initial_money) / real_initial_money
        ) * 100
        total_gains = real_starting_money - real_initial_money
        return states_buy, states_sell, total_gains, invest

# %%
stocks = [i for i in os.listdir(os.getcwd()) if '.csv' in i and not 'TWTR' in i]
stocks
# Out:
# ['AMD.csv',
#  'CPRT.csv',
#  'FB.csv',
#  'FSV.csv',
#  'GOOG.csv',
#  'GWR.csv',
#  'LB.csv',
#  'LYFT.csv',
#  'MTDR.csv',
#  'SINA.csv',
#  'TSLA.csv']

# %% [markdown]
# We train on all stocks, downloaded except for Twitter. We use Twitter for testing.

# %%
skip = 1
layer_size = 500
output_size = 3
window_size = 20

# %%
model = Model(input_size = input_size, layer_size = layer_size, output_size = output_size)
agent = None

for no, stock in enumerate(stocks):
    print('training stock %s'%(stock))
    df = pd.read_csv(stock)
    real_trend = df['Close'].tolist()
    parameters = [df['Close'].tolist(), df['Volume'].tolist()]
    minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
    scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
    initial_money = np.max(parameters[0]) * 2
    
    if no == 0:
        agent = Agent(model = model,
                      timeseries = scaled_parameters,
                      skip = skip,
                      initial_money = initial_money,
                      real_trend = real_trend,
                      minmax = minmax)
    else:
        agent.change_data(timeseries = scaled_parameters,
                          skip = skip,
                          initial_money = initial_money,
                          real_trend = real_trend,
                          minmax = minmax)
    
    agent.fit(iterations = 100, checkpoint = 10)
    print()
# Out:
# training stock AMD.csv
# iter 10. reward: 28.304434
# iter 20. reward: 38.671113
# iter 30. reward: 46.357335
# iter 40. reward: 51.345125
# iter 50. reward: 52.604715
# iter 60. reward: 52.620456
# iter 70. reward: 56.069928
# iter 80. reward: 52.499336
# iter 90. reward: 55.461589
# iter 100. reward: 54.443629
# time taken to train: 89.00323057174683 seconds
#
# training stock CPRT.csv
# iter 10. reward: 12.873417
# iter 20. reward: 12.984954
# iter 30. reward: 12.463389
# iter 40. reward: 13.440278
# iter 50. reward: 22.135093
# iter 60. reward: 24.849061
# iter 70. reward: 27.733836
# iter 80. reward: 26.744989
# iter 90. reward: 21.997417
# iter 100. reward: 34.224882
# time taken to train: 95.88094067573547 seconds
#
# training stock FB.csv
# iter 10. reward: -19.421290
# iter 20. reward: -18.895932
# iter 30. reward: -6.089908
# iter 40. reward: -2.139918
# iter 50. reward: 0.241191
# iter 60. reward: -11.860114
# iter 70. reward: 1.368367
# iter 80. reward: 0.945279
# iter 90. reward: 5.299000
# iter 100. reward: 6.851895
# time taken to train: 93.41414761543274 seconds
#
# training stock FSV.csv
# iter 10. reward: 9.564337
# iter 20. reward: 15.165996
# iter 30. reward: 18.451818
# iter 40. reward: 19.322126
# iter 50. reward: 22.564463
# iter 60. reward: 22.343915
# iter 70. reward: 21.504037
# iter 80. reward: 22.968571
# iter 90. reward: 21.589272
# iter 100. reward: 25.227647
# time taken to train: 98.7325792312622 seconds
#
# training stock GOOG.csv
# iter 10. reward: 14.793875
# iter 20. reward: 19.117137
# iter 30. reward: 23.746988
# iter 40. reward: 24.684328
# iter 50. reward: 22.770607
# iter 60. reward: 30.424051
# iter 70. reward: 32.257907
# iter 80. reward: 32.160946
# iter 90. reward: 33.941295
# iter 100. reward: 35.938470
# time taken to train: 95.28507804870605 seconds
#
# training stock GWR.csv
# iter 10. reward: -13.627195
# iter 20. reward: -12.571725
# iter 30. reward: -13.898878
# iter 40. reward: -14.534294
# iter 50. reward: -2.514263
# iter 60. reward: -0.345447
# iter 70. reward: 8.546410
# iter 80. reward: 18.622849
# iter 90. reward: 21.195638
# iter 100. reward: 23.835120
# time taken to train: 83.73375058174133 seconds
#
# training stock LB.csv
# iter 10. reward: -18.240501
# iter 20. reward: -9.657269
# iter 30. reward: -6.007979
# iter 40. reward: -4.379082
# iter 50. reward: -4.321810
# iter 60. reward: -3.706198
# iter 70. reward: -2.219253
# iter 80. reward: 1.318234
# iter 90. reward: 6.901559
# iter 100. reward: 8.902723
# time taken to train: 96.32093572616577 seconds
#
# training stock LYFT.csv
# iter 10. reward: 1.017949
# iter 20. reward: 0.745563
# iter 30. reward: 2.793353
# iter 40. reward: 2.793353
# iter 50. reward: 2.793353
# iter 60. reward: 2.793353
# iter 70. reward: 2.793353
# iter 80. reward: 2.793353
# iter 90. reward: 2.793353
# iter 100. reward: 2.793353
# time taken to train: 20.992857217788696 seconds
#
# training stock MTDR.csv
# iter 10. reward: -21.307150
# iter 20. reward: -20.031321
# iter 30. reward: -20.730755
# iter 40. reward: -20.325351
# iter 50. reward: 3.892160
# iter 60. reward: 6.695896
# iter 70. reward: 9.931448
# iter 80. reward: 9.943836
# iter 90. reward: 10.088495
# iter 100. reward: 10.521022
# time taken to train: 90.05788683891296 seconds
#
# training stock SINA.csv
# iter 10. reward: 3.600333
# iter 20. reward: 3.721178
# iter 30. reward: 6.938600
# iter 40. reward: 8.685286
# iter 50. reward: 11.462497
# iter 60. reward: 11.829779
# iter 70. reward: 12.134855
# iter 80. reward: 12.157668
# iter 90. reward: 10.932719
# iter 100. reward: 13.314932
# time taken to train: 92.31330156326294 seconds
#
# training stock TSLA.csv
# iter 10. reward: 3.135567
# iter 20. reward: 5.284239
# iter 30. reward: 8.713055
# iter 40. reward: 11.632309
# iter 50. reward: 11.668244
# iter 60. reward: 12.520662
# iter 70. reward: 16.519284
# iter 80. reward: 17.889942
# iter 90. reward: 16.001473
# iter 100. reward: 19.694008
# time taken to train: 92.57478332519531 seconds

# %% [markdown]
# If we see the whole training session on certain stocks are negatives (like FB), means that, that stock markets are losing very bad

# %%
df = pd.read_csv('GOOG.csv')
real_trend = df['Close'].tolist()
parameters = [df['Close'].tolist(), df['Volume'].tolist()]
minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
initial_money = np.max(parameters[0]) * 2

    
agent.change_data(timeseries = scaled_parameters,
                  skip = skip,
                  initial_money = initial_money,
                  real_trend = real_trend,
                  minmax = minmax)

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# 0 [1. 0. 0.]
# 1 [1. 0. 0.]
# 2 [1. 0. 0.]
# 3 [1. 0. 0.]
# 4 [1. 0. 0.]
# 5 [1. 0. 0.]
# 6 [1. 0. 0.]
# 7 [0. 1. 0.]
# day 7: buy 1 unit at price 1139.290039, total balance 1435.869873
# 8 [1. 0. 0.]
# 9 [1. 0. 0.]
# 10 [1. 0. 0.]
# 11 [0. 0. 1.]
# day 11, sell 1 unit at price 1120.869995, investment -1.616800 %, total balance 2556.739868,
# 12 [1. 0. 0.]
# 13 [1. 0. 0.]
# 14 [0. 0. 1.]
# 15 [1. 0. 0.]
# 16 [0. 0. 1.]
# 17 [1. 0. 0.]
# 18 [1. 0. 0.]
# 19 [1. 0. 0.]
# 20 [1. 0. 0.]
# 21 [1. 0. 0.]
# 22 [1. 0. 0.]
# 23 [1. 0. 0.]
# 24 [0. 0. 1.]
# 25 [0. 0. 1.]
# 26 [0. 1. 0.]
# day 26: buy 1 unit at price 1115.650024, total balance 1441.089844
# 27 [0. 0. 1.]
# day 27, sell 1 unit at price 1127.459961, investment 1.058570 %, total balance 2568.549805,
# 28 [0. 0. 1.]
# 29 [1. 0. 0.]
# 30 [1. 0. 0.]
# 31 [1. 0. 0.]
# 32 [1. 0. 0.]
# 33 [1. 0. 0.]
# 34 [1. 0. 0.]
# 35 [0. 0. 1.]
# 36 [0. 0. 1.]
# 37 [0. 0. 1.]
# 38 [0. 0. 1.]
# 39 [0. 1. 0.]
# day 39: buy 1 unit at price 1186.959961, total balance 1381.589844
# 40 [0. 0. 1.]
# day 40, sell 1 unit at price 1184.910034, investment -0.172704 %, total balance 2566.499878,
# 41 [1. 0. 0.]
# 42 [1. 0. 0.]
# 43 [1. 0. 0.]
# 44 [1. 0. 0.]
# 45 [1. 0. 0.]
# 46 [1. 0. 0.]
# 47 [1. 0. 0.]
# 48 [1. 0. 0.]
# 49 [1. 0. 0.]
# 50 [1. 0. 0.]
# 51 [1. 0. 0.]
# 52 [1. 0. 0.]
# 53 [1. 0. 0.]
# 54 [1. 0. 0.]
# 55 [1. 0. 0.]
# 56 [1. 0. 0.]
# 57 [1. 0. 0.]
# 58 [1. 0. 0.]
# 59 [1. 0. 0.]
# 60 [0. 0. 1.]
# 61 [0. 0. 1.]
# 62 [0. 1. 0.]
# day 62: buy 1 unit at price 1201.619995, total balance 1364.879883
# 63 [0. 0. 1.]
# day 63, sell 1 unit at price 1207.329956, investment 0.475189 %, total balance 2572.209839,
# 64 [0. 0. 1.]
# 65 [1. 0. 0.]
# 66 [0. 1. 0.]
# day 66: buy 1 unit at price 1241.819946, total balance 1330.389893
# 67 [1. 0. 0.]
# 68 [1. 0. 0.]
# 69 [1. 0. 0.]
# 70 [1. 0. 0.]
# 71 [0. 0. 1.]
# day 71, sell 1 unit at price 1197.000000, investment -3.609215 %, total balance 2527.389893,
# 72 [0. 0. 1.]
# 73 [0. 1. 0.]
# day 73: buy 1 unit at price 1171.439941, total balance 1355.949952
# 74 [0. 1. 0.]
# day 74: buy 1 unit at price 1164.829956, total balance 191.119996
# 75 [0. 1. 0.]
# day 75: buy 1 unit at price 1164.640015, total balance -973.520019
# 76 [0. 1. 0.]
# 77 [0. 0. 1.]
# day 77, sell 1 unit at price 1162.819946, investment -0.735846 %, total balance 189.299927,
# 78 [0. 0. 1.]
# day 78, sell 1 unit at price 1175.329956, investment 0.901419 %, total balance 1364.629883,
# 79 [1. 0. 0.]
# 80 [1. 0. 0.]
# 81 [1. 0. 0.]
# 82 [0. 1. 0.]
# day 82: buy 1 unit at price 1171.089966, total balance 193.539917
# 83 [1. 0. 0.]
# 84 [1. 0. 0.]
# 85 [0. 1. 0.]
# day 85: buy 1 unit at price 1173.369995, total balance -979.830078
# 86 [0. 0. 1.]
# day 86, sell 1 unit at price 1184.650024, investment 1.718128 %, total balance 204.819946,
# 87 [0. 0. 1.]
# day 87, sell 1 unit at price 1180.489990, investment 0.802673 %, total balance 1385.309936,
# 88 [0. 1. 0.]
# day 88: buy 1 unit at price 1194.640015, total balance 190.669921
# 89 [0. 0. 1.]
# day 89, sell 1 unit at price 1193.469971, investment 1.713013 %, total balance 1384.139892,
# 90 [0. 0. 1.]
# day 90, sell 1 unit at price 1195.310059, investment 0.056088 %, total balance 2579.449951,
# 91 [0. 1. 0.]
# day 91: buy 1 unit at price 1200.109985, total balance 1379.339966
# 92 [0. 0. 1.]
# day 92, sell 1 unit at price 1202.949951, investment 0.236642 %, total balance 2582.289917,
# 93 [1. 0. 0.]
# 94 [1. 0. 0.]
# 95 [0. 0. 1.]
# 96 [1. 0. 0.]
# 97 [0. 1. 0.]
# day 97: buy 1 unit at price 1081.219971, total balance 1501.069946
# 98 [0. 0. 1.]
# day 98, sell 1 unit at price 1079.319946, investment -0.175730 %, total balance 2580.389892,
# 99 [0. 1. 0.]
# day 99: buy 1 unit at price 1110.079956, total balance 1470.309936
# 100 [1. 0. 0.]
# 101 [0. 1. 0.]
# day 101: buy 1 unit at price 1121.280029, total balance 349.029907
# 102 [0. 1. 0.]
# day 102: buy 1 unit at price 1115.689941, total balance -766.660034
# 103 [0. 0. 1.]
# day 103, sell 1 unit at price 1087.969971, investment -1.991747 %, total balance 321.309937,
# 104 [1.00000000e+000 3.14942558e-141 0.00000000e+000]
# 105 [0. 1. 0.]
# day 105: buy 1 unit at price 1101.160034, total balance -779.850097
# 106 [0. 0. 1.]
# day 106, sell 1 unit at price 1103.689941, investment -1.568751 %, total balance 323.839844,
# 107 [0.00000000e+00 1.10891083e-49 1.00000000e+00]
# day 107, sell 1 unit at price 1050.709961, investment -5.824197 %, total balance 1374.549805,
# 108 [0.00000000e+000 7.87690722e-301 1.00000000e+000]
# day 108, sell 1 unit at price 1095.569946, investment -0.507654 %, total balance 2470.119751,
# 109 [0. 0. 1.]
# 110 [0. 1. 0.]
# day 110: buy 1 unit at price 1020.080017, total balance 1450.039734
# 111 [0. 1. 0.]
# day 111: buy 1 unit at price 1036.209961, total balance 413.829773
# 112 [0. 0. 1.]
# day 112, sell 1 unit at price 1076.770020, investment 5.557407 %, total balance 1490.599793,
# 113 [0. 1. 0.]
# day 113: buy 1 unit at price 1070.000000, total balance 420.599793
# 114 [0. 0. 1.]
# day 114, sell 1 unit at price 1057.790039, investment 2.082597 %, total balance 1478.389832,
# 115 [0. 1. 0.]
# day 115: buy 1 unit at price 1040.089966, total balance 438.299866
# 116 [1. 0. 0.]
# 117 [0. 0. 1.]
# day 117, sell 1 unit at price 1093.390015, investment 2.185983 %, total balance 1531.689881,
# 118 [0. 1. 0.]
# day 118: buy 1 unit at price 1082.400024, total balance 449.289857
# 119 [0. 1. 0.]
# day 119: buy 1 unit at price 1066.150024, total balance -616.860167
# 120 [0. 0. 1.]
# day 120, sell 1 unit at price 1038.630005, investment -0.140369 %, total balance 421.769838,
# 121 [0. 1. 0.]
# day 121: buy 1 unit at price 1036.050049, total balance -614.280211
# 122 [0. 1. 0.]
# day 122: buy 1 unit at price 1043.660034, total balance -1657.940245
# 123 [0. 0. 1.]
# day 123, sell 1 unit at price 1064.709961, investment -1.634337 %, total balance -593.230284,
# 124 [0.00000000e+000 1.00000000e+000 1.79077266e-146]
# day 124: buy 1 unit at price 1061.489990, total balance -1654.720274
# 125 [0. 0. 1.]
# day 125, sell 1 unit at price 1020.000000, investment -4.328661 %, total balance -634.720274,
# 126 [1. 0. 0.]
# 127 [0. 1. 0.]
# day 127: buy 1 unit at price 1037.609985, total balance -1672.330259
# 128 [0. 0. 1.]
# day 128, sell 1 unit at price 1023.880005, investment -1.174658 %, total balance -648.450254,
# 129 [0. 0. 1.]
# day 129, sell 1 unit at price 1048.619995, investment 0.475247 %, total balance 400.169741,
# 130 [0. 0. 1.]
# day 130, sell 1 unit at price 1044.410034, investment -1.609055 %, total balance 1444.579775,
# 131 [0. 0. 1.]
# day 131, sell 1 unit at price 1086.229980, investment 4.685768 %, total balance 2530.809755,
# 132 [4.26668497e-253 1.00000000e+000 0.00000000e+000]
# day 132: buy 1 unit at price 1088.300049, total balance 1442.509706
# 133 [1. 0. 0.]
# 134 [1. 0. 0.]
# 135 [0. 1. 0.]
# day 135: buy 1 unit at price 1050.819946, total balance 391.689760
# 136 [0. 0. 1.]
# day 136, sell 1 unit at price 1068.729980, investment -1.798224 %, total balance 1460.419740,
# 137 [0. 1. 0.]
# day 137: buy 1 unit at price 1036.579956, total balance 423.839784
# 138 [0. 0. 1.]
# day 138, sell 1 unit at price 1039.550049, investment -1.072486 %, total balance 1463.389833,
# 139 [0. 1. 0.]
# day 139: buy 1 unit at price 1051.750000, total balance 411.639833
# 140 [0. 1. 0.]
# day 140: buy 1 unit at price 1063.680054, total balance -652.040221
# 141 [0. 0. 1.]
# day 141, sell 1 unit at price 1061.900024, investment 2.442655 %, total balance 409.859803,
# 142 [0. 0. 1.]
# day 142, sell 1 unit at price 1042.099976, investment -0.917521 %, total balance 1451.959779,
# 143 [1. 0. 0.]
# 144 [1. 0. 0.]
# 145 [0. 0. 1.]
# day 145, sell 1 unit at price 1023.010010, investment -3.823522 %, total balance 2474.969789,
# 146 [1. 0. 0.]
# 147 [1. 0. 0.]
# 148 [1. 0. 0.]
# 149 [0. 1. 0.]
# day 149: buy 1 unit at price 1039.459961, total balance 1435.509828
# 150 [1. 0. 0.]
# 151 [0. 1. 0.]
# day 151: buy 1 unit at price 1037.079956, total balance 398.429872
# 152 [0. 0. 1.]
# day 152, sell 1 unit at price 1035.609985, investment -0.370382 %, total balance 1434.039857,
# 153 [0. 1. 0.]
# day 153: buy 1 unit at price 1045.849976, total balance 388.189881
# 154 [0. 1. 0.]
# day 154: buy 1 unit at price 1016.059998, total balance -627.870117
# 155 [0. 0. 1.]
# day 155, sell 1 unit at price 1070.709961, investment 3.242759 %, total balance 442.839844,
# 156 [1. 0. 0.]
# 157 [0. 0. 1.]
# day 157, sell 1 unit at price 1076.280029, investment 2.909600 %, total balance 1519.119873,
# 158 [0. 0. 1.]
# day 158, sell 1 unit at price 1074.660034, investment 5.767379 %, total balance 2593.779907,
# 159 [1. 0. 0.]
# 160 [0. 0. 1.]
# 161 [0. 0. 1.]
# 162 [1. 0. 0.]
# 163 [1. 0. 0.]
# 164 [0. 1. 0.]
# day 164: buy 1 unit at price 1089.900024, total balance 1503.879883
# 165 [1. 0. 0.]
# 166 [1. 0. 0.]
# 167 [1. 0. 0.]
# 168 [0. 0. 1.]
# day 168, sell 1 unit at price 1073.900024, investment -1.468025 %, total balance 2577.779907,
# 169 [1. 0. 0.]
# 170 [0. 0. 1.]
# 171 [1. 0. 0.]
# 172 [1. 0. 0.]
# 173 [1. 0. 0.]
# 174 [0. 0. 1.]
# 175 [1. 0. 0.]
# 176 [1. 0. 0.]
# 177 [1. 0. 0.]
# 178 [1. 0. 0.]
# 179 [1. 0. 0.]
# 180 [1. 0. 0.]
# 181 [0. 0. 1.]
# 182 [0. 1. 0.]
# day 182: buy 1 unit at price 1120.160034, total balance 1457.619873
# 183 [0. 0. 1.]
# day 183, sell 1 unit at price 1121.670044, investment 0.134803 %, total balance 2579.289917,
# 184 [0. 0. 1.]
# 185 [1. 0. 0.]
# 186 [2.96657649e-140 1.00000000e+000 0.00000000e+000]
# day 186: buy 1 unit at price 1113.800049, total balance 1465.489868
# 187 [1. 0. 0.]
# 188 [1. 0. 0.]
# 189 [0. 0. 1.]
# day 189, sell 1 unit at price 1109.400024, investment -0.395046 %, total balance 2574.889892,
# 190 [1. 0. 0.]
# 191 [1. 0. 0.]
# 192 [1. 0. 0.]
# 193 [1. 0. 0.]
# 194 [0. 1. 0.]
# day 194: buy 1 unit at price 1147.800049, total balance 1427.089843
# 195 [0. 0. 1.]
# day 195, sell 1 unit at price 1162.030029, investment 1.239761 %, total balance 2589.119872,
# 196 [1. 0. 0.]
# 197 [0. 0. 1.]
# 198 [1. 0. 0.]
# 199 [1. 0. 0.]
# 200 [0. 0. 1.]
# 201 [1. 0. 0.]
# 202 [1. 0. 0.]
# 203 [1. 0. 0.]
# 204 [1. 0. 0.]
# 205 [1. 0. 0.]
# 206 [1. 0. 0.]
# 207 [1. 0. 0.]
# 208 [0. 0. 1.]
# 209 [1. 0. 0.]
# 210 [1. 0. 0.]
# 211 [1. 0. 0.]
# 212 [1. 0. 0.]
# 213 [1. 0. 0.]
# 214 [0. 0. 1.]
# 215 [1. 0. 0.]
# 216 [1. 0. 0.]
# 217 [1. 0. 0.]
# 218 [1. 0. 0.]
# 219 [0. 0. 1.]
# 220 [1. 0. 0.]
# 221 [1. 0. 0.]
# 222 [0. 0. 1.]
# 223 [1. 0. 0.]
# 224 [0. 0. 1.]
# 225 [0. 0. 1.]
# 226 [0. 1. 0.]
# day 226: buy 1 unit at price 1236.339966, total balance 1352.779906
# 227 [0. 0. 1.]
# day 227, sell 1 unit at price 1236.369995, investment 0.002429 %, total balance 2589.149901,
# 228 [1. 0. 0.]
# 229 [1.00000000e+00 0.00000000e+00 9.28317784e-90]
# 230 [1. 0. 0.]
# 231 [1. 0. 0.]
# 232 [1. 0. 0.]
# 233 [1. 0. 0.]
# 234 [1. 0. 0.]
# 235 [1. 0. 0.]
# 236 [0. 1. 0.]
# 237 [1. 0. 0.]
# 238 [0. 1. 0.]
# 239 [0. 0. 1.]
# 240 [1. 0. 0.]
# 241 [1. 0. 0.]
# 242 [0.00000000e+00 1.39591176e-29 1.00000000e+00]
# 243 [1. 0. 0.]
# 244 [1. 0. 0.]
# 245 [0. 0. 1.]
# 246 [1. 0. 0.]
# 247 [0. 1. 0.]
# 248 [0. 0. 1.]
# 249 [0. 1. 0.]
# 250 [0. 1. 0.]

# %%
fig = plt.figure(figsize = (15, 5))
plt.plot(df['Close'], color='r', lw=2.)
plt.plot(df['Close'], '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(df['Close'], 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('GOOG total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()

# %%
df = pd.read_csv('TWTR.csv')
real_trend = df['Close'].tolist()
parameters = [df['Close'].tolist(), df['Volume'].tolist()]
minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
initial_money = np.max(parameters[0]) * 2

agent.change_data(timeseries = scaled_parameters,
                  skip = skip,
                  initial_money = initial_money,
                  real_trend = real_trend,
                  minmax = minmax)

states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# 0 [1. 0. 0.]
# 1 [1. 0. 0.]
# 2 [1. 0. 0.]
# 3 [1. 0. 0.]
# 4 [1. 0. 0.]
# 5 [1. 0. 0.]
# 6 [1. 0. 0.]
# 7 [1. 0. 0.]
# 8 [1. 0. 0.]
# 9 [1. 0. 0.]
# 10 [1. 0. 0.]
# 11 [0. 0. 1.]
# 12 [1. 0. 0.]
# 13 [1. 0. 0.]
# 14 [0. 0. 1.]
# 15 [1. 0. 0.]
# 16 [1. 0. 0.]
# 17 [1. 0. 0.]
# 18 [1. 0. 0.]
# 19 [1. 0. 0.]
# 20 [1. 0. 0.]
# 21 [1. 0. 0.]
# 22 [1. 0. 0.]
# 23 [1. 0. 0.]
# 24 [1. 0. 0.]
# 25 [1. 0. 0.]
# 26 [1. 0. 0.]
# 27 [1. 0. 0.]
# 28 [0. 0. 1.]
# 29 [1. 0. 0.]
# 30 [1. 0. 0.]
# 31 [1. 0. 0.]
# 32 [1. 0. 0.]
# 33 [0. 1. 0.]
# day 33: buy 1 unit at price 43.869999, total balance 49.649997
# 34 [1. 0. 0.]
# 35 [0. 1. 0.]
# day 35: buy 1 unit at price 44.490002, total balance 5.159995
# 36 [0. 0. 1.]
# day 36, sell 1 unit at price 44.259998, investment 0.888988 %, total balance 49.419993,
# 37 [0. 0. 1.]
# day 37, sell 1 unit at price 44.709999, investment 0.494486 %, total balance 94.129992,
# 38 [1.00000000e+000 5.82891236e-315 0.00000000e+000]
# 39 [0. 0. 1.]
# 40 [0. 1. 0.]
# day 40: buy 1 unit at price 43.419998, total balance 50.709994
# 41 [8.91167399e-35 1.00000000e+00 0.00000000e+00]
# day 41: buy 1 unit at price 43.310001, total balance 7.399993
# 42 [0. 0. 1.]
# day 42, sell 1 unit at price 42.169998, investment -2.878858 %, total balance 49.569991,
# 43 [1. 0. 0.]
# 44 [0. 1. 0.]
# day 44: buy 1 unit at price 42.939999, total balance 6.629992
# 45 [0. 0. 1.]
# day 45, sell 1 unit at price 34.119999, investment -21.219122 %, total balance 40.749991,
# 46 [1. 0. 0.]
# 47 [0. 1. 0.]
# day 47: buy 1 unit at price 31.870001, total balance 8.879990
# 48 [0. 1. 0.]
# 49 [0. 1. 0.]
# 50 [0. 0. 1.]
# day 50, sell 1 unit at price 31.959999, investment -25.570564 %, total balance 40.839989,
# 51 [0. 0. 1.]
# day 51, sell 1 unit at price 32.980000, investment 3.482896 %, total balance 73.819989,
# 52 [0. 1. 0.]
# day 52: buy 1 unit at price 32.669998, total balance 41.149991
# 53 [0. 1. 0.]
# day 53: buy 1 unit at price 31.840000, total balance 9.309991
# 54 [0. 1. 0.]
# 55 [0. 1. 0.]
# 56 [0. 0. 1.]
# day 56, sell 1 unit at price 32.799999, investment 0.397922 %, total balance 42.109990,
# 57 [0. 1. 0.]
# day 57: buy 1 unit at price 33.189999, total balance 8.919991
# 58 [0. 0. 1.]
# day 58, sell 1 unit at price 32.380001, investment 1.695983 %, total balance 41.299992,
# 59 [0. 0. 1.]
# day 59, sell 1 unit at price 32.830002, investment -1.084655 %, total balance 74.129994,
# 60 [0. 1. 0.]
# day 60: buy 1 unit at price 32.730000, total balance 41.399994
# 61 [0. 0. 1.]
# day 61, sell 1 unit at price 32.599998, investment -0.397195 %, total balance 73.999992,
# 62 [0. 1. 0.]
# day 62: buy 1 unit at price 33.689999, total balance 40.309993
# 63 [0. 1. 0.]
# day 63: buy 1 unit at price 33.810001, total balance 6.499992
# 64 [0. 0. 1.]
# day 64, sell 1 unit at price 33.880001, investment 0.563972 %, total balance 40.379993,
# 65 [0. 0. 1.]
# day 65, sell 1 unit at price 34.279999, investment 1.390115 %, total balance 74.659992,
# 66 [0. 0. 1.]
# 67 [0. 0. 1.]
# 68 [1. 0. 0.]
# 69 [1. 0. 0.]
# 70 [0. 0. 1.]
# 71 [6.66674763e-70 0.00000000e+00 1.00000000e+00]
# 72 [1. 0. 0.]
# 73 [1. 0. 0.]
# 74 [1.00000000e+000 6.19246706e-107 0.00000000e+000]
# 75 [0. 0. 1.]
# 76 [0. 1. 0.]
# day 76: buy 1 unit at price 30.889999, total balance 43.769993
# 77 [0. 0. 1.]
# day 77, sell 1 unit at price 29.750000, investment -3.690512 %, total balance 73.519993,
# 78 [1. 0. 0.]
# 79 [0. 1. 0.]
# day 79: buy 1 unit at price 30.120001, total balance 43.399992
# 80 [1. 0. 0.]
# 81 [0. 1. 0.]
# day 81: buy 1 unit at price 29.219999, total balance 14.179993
# 82 [0. 1. 0.]
# 83 [0. 0. 1.]
# day 83, sell 1 unit at price 29.850000, investment -0.896418 %, total balance 44.029993,
# 84 [0. 1. 0.]
# day 84: buy 1 unit at price 28.500000, total balance 15.529993
# 85 [0. 0. 1.]
# day 85, sell 1 unit at price 28.600000, investment -2.121831 %, total balance 44.129993,
# 86 [0. 0. 1.]
# day 86, sell 1 unit at price 29.110001, investment 2.140354 %, total balance 73.239994,
# 87 [0.00000000e+000 1.00000000e+000 2.22224416e-253]
# day 87: buy 1 unit at price 29.010000, total balance 44.229994
# 88 [0. 0. 1.]
# day 88, sell 1 unit at price 29.420000, investment 1.413306 %, total balance 73.649994,
# 89 [0. 0. 1.]
# 90 [0. 1. 0.]
# day 90: buy 1 unit at price 28.309999, total balance 45.339995
# 91 [0. 0. 1.]
# day 91, sell 1 unit at price 28.190001, investment -0.423871 %, total balance 73.529996,
# 92 [0. 0. 1.]
# 93 [0. 0. 1.]
# 94 [0. 0. 1.]
# 95 [0. 0. 1.]
# 96 [1. 0. 0.]
# 97 [0. 1. 0.]
# day 97: buy 1 unit at price 26.790001, total balance 46.739995
# 98 [0. 1. 0.]
# day 98: buy 1 unit at price 27.000000, total balance 19.739995
# 99 [0. 0. 1.]
# day 99, sell 1 unit at price 27.990000, investment 4.479279 %, total balance 47.729995,
# 100 [1. 0. 0.]
# 101 [0. 1. 0.]
# day 101: buy 1 unit at price 29.870001, total balance 17.859994
# 102 [0. 1. 0.]
# day 102: buy 1 unit at price 29.549999, total balance -11.690005
# 103 [0. 0. 1.]
# day 103, sell 1 unit at price 29.290001, investment 8.481485 %, total balance 17.599996,
# 104 [1. 0. 0.]
# 105 [0. 0. 1.]
# day 105, sell 1 unit at price 29.180000, investment -2.310013 %, total balance 46.779996,
# 106 [1. 0. 0.]
# 107 [0. 1. 0.]
# day 107: buy 1 unit at price 27.540001, total balance 19.239995
# 108 [1. 0. 0.]
# 109 [1. 0. 0.]
# 110 [1. 0. 0.]
# 111 [1. 0. 0.]
# 112 [1. 0. 0.]
# 113 [0. 0. 1.]
# day 113, sell 1 unit at price 34.619999, investment 17.157361 %, total balance 53.859994,
# 114 [1. 0. 0.]
# 115 [1. 0. 0.]
# 116 [0. 0. 1.]
# day 116, sell 1 unit at price 34.419998, investment 24.981833 %, total balance 88.279992,
# 117 [1. 0. 0.]
# 118 [1. 0. 0.]
# 119 [0. 0. 1.]
# 120 [1. 0. 0.]
# 121 [0. 1. 0.]
# day 121: buy 1 unit at price 32.490002, total balance 55.789990
# 122 [1.00000000e+000 0.00000000e+000 3.21825013e-309]
# 123 [1. 0. 0.]
# 124 [1. 0. 0.]
# 125 [1. 0. 0.]
# 126 [1. 0. 0.]
# 127 [0. 0. 1.]
# day 127, sell 1 unit at price 31.610001, investment -2.708529 %, total balance 87.399991,
# 128 [2.65025148e-39 1.00000000e+00 0.00000000e+00]
# day 128: buy 1 unit at price 31.120001, total balance 56.279990
# 129 [1. 0. 0.]
# 130 [0. 0. 1.]
# day 130, sell 1 unit at price 32.610001, investment 4.787918 %, total balance 88.889991,
# 131 [0. 0. 1.]
# 132 [0. 0. 1.]
# 133 [1.00000000e+00 4.17329169e-52 0.00000000e+00]
# 134 [0. 0. 1.]
# 135 [0.00000000e+00 4.42203365e-27 1.00000000e+00]
# 136 [0. 1. 0.]
# day 136: buy 1 unit at price 32.959999, total balance 55.929992
# 137 [0. 0. 1.]
# day 137, sell 1 unit at price 32.830002, investment -0.394408 %, total balance 88.759994,
# 138 [1. 0. 0.]
# 139 [1. 0. 0.]
# 140 [1.00000000e+000 0.00000000e+000 1.74911168e-172]
# 141 [0. 0. 1.]
# 142 [0. 0. 1.]
# 143 [0. 0. 1.]
# 144 [1. 0. 0.]
# 145 [0. 0. 1.]
# 146 [1. 0. 0.]
# 147 [1. 0. 0.]
# 148 [0.00000000e+000 1.20015322e-312 1.00000000e+000]
# 149 [0. 1. 0.]
# day 149: buy 1 unit at price 28.660000, total balance 60.099994
# 150 [0. 1. 0.]
# day 150: buy 1 unit at price 28.680000, total balance 31.419994
# 151 [0. 0. 1.]
# day 151, sell 1 unit at price 28.430000, investment -0.802512 %, total balance 59.849994,
# 152 [1. 0. 0.]
# 153 [0. 1. 0.]
# day 153: buy 1 unit at price 28.809999, total balance 31.039995
# 154 [0. 1. 0.]
# day 154: buy 1 unit at price 27.990000, total balance 3.049995
# 155 [1. 0. 0.]
# 156 [1. 0. 0.]
# 157 [0. 0. 1.]
# day 157, sell 1 unit at price 31.799999, investment 10.878658 %, total balance 34.849994,
# 158 [0. 0. 1.]
# day 158, sell 1 unit at price 32.250000, investment 11.940302 %, total balance 67.099994,
# 159 [0. 0. 1.]
# day 159, sell 1 unit at price 33.090000, investment 18.220793 %, total balance 100.189994,
# 160 [0. 0. 1.]
# 161 [0. 0. 1.]
# 162 [0. 0. 1.]
# 163 [0. 1. 0.]
# day 163: buy 1 unit at price 32.470001, total balance 67.719993
# 164 [0. 0. 1.]
# day 164, sell 1 unit at price 32.849998, investment 1.170302 %, total balance 100.569991,
# 165 [0. 0. 1.]
# 166 [1. 0. 0.]
# 167 [1. 0. 0.]
# 168 [4.58870812e-107 0.00000000e+000 1.00000000e+000]
# 169 [1. 0. 0.]
# 170 [1. 0. 0.]
# 171 [1. 0. 0.]
# 172 [1. 0. 0.]
# 173 [1. 0. 0.]
# 174 [1. 0. 0.]
# 175 [1. 0. 0.]
# 176 [1. 0. 0.]
# 177 [1. 0. 0.]
# 178 [0. 0. 1.]
# 179 [1. 0. 0.]
# 180 [1. 0. 0.]
# 181 [1. 0. 0.]
# 182 [0. 1. 0.]
# day 182: buy 1 unit at price 31.120001, total balance 69.449990
# 183 [0. 0. 1.]
# day 183, sell 1 unit at price 30.959999, investment -0.514145 %, total balance 100.409989,
# 184 [0. 0. 1.]
# 185 [1. 0. 0.]
# 186 [1. 0. 0.]
# 187 [1. 0. 0.]
# 188 [0. 1. 0.]
# day 188: buy 1 unit at price 31.709999, total balance 68.699990
# 189 [0. 0. 1.]
# day 189, sell 1 unit at price 31.990000, investment 0.883005 %, total balance 100.689990,
# 190 [1. 0. 0.]
# 191 [1.00000000e+000 5.28616161e-309 0.00000000e+000]
# 192 [0. 0. 1.]
# 193 [0. 0. 1.]
# 194 [0. 1. 0.]
# day 194: buy 1 unit at price 30.500000, total balance 70.189990
# 195 [0. 1. 0.]
# day 195: buy 1 unit at price 31.030001, total balance 39.159989
# 196 [0. 0. 1.]
# day 196, sell 1 unit at price 30.799999, investment 0.983603 %, total balance 69.959988,
# 197 [0. 0. 1.]
# day 197, sell 1 unit at price 30.120001, investment -2.932646 %, total balance 100.079989,
# 198 [1. 0. 0.]
# 199 [1. 0. 0.]
# 200 [1. 0. 0.]
# 201 [0. 0. 1.]
# 202 [0. 0. 1.]
# 203 [1. 0. 0.]
# 204 [0. 1. 0.]
# day 204: buy 1 unit at price 31.080000, total balance 68.999989
# 205 [0. 0. 1.]
# day 205, sell 1 unit at price 31.270000, investment 0.611326 %, total balance 100.269989,
# 206 [1. 0. 0.]
# 207 [0.00000000e+000 1.00000000e+000 2.02457878e-211]
# day 207: buy 1 unit at price 32.610001, total balance 67.659988
# 208 [0. 0. 1.]
# day 208, sell 1 unit at price 33.020000, investment 1.257280 %, total balance 100.679988,
# 209 [1. 0. 0.]
# 210 [1. 0. 0.]
# 211 [5.3320845e-91 0.0000000e+00 1.0000000e+00]
# 212 [1. 0. 0.]
# 213 [0. 0. 1.]
# 214 [1. 0. 0.]
# 215 [1. 0. 0.]
# 216 [1. 0. 0.]
# 217 [1. 0. 0.]
# 218 [1. 0. 0.]
# 219 [1. 0. 0.]
# 220 [1. 0. 0.]
# 221 [1. 0. 0.]
# 222 [1. 0. 0.]
# 223 [1. 0. 0.]
# 224 [1. 0. 0.]
# 225 [0. 0. 1.]
# 226 [1. 0. 0.]
# 227 [0. 0. 1.]
# 228 [1. 0. 0.]
# 229 [1. 0. 0.]
# 230 [1. 0. 0.]
# 231 [0. 0. 1.]
# 232 [1. 0. 0.]
# 233 [1. 0. 0.]
# 234 [0. 0. 1.]
# 235 [1. 0. 0.]
# 236 [1. 0. 0.]
# 237 [0. 0. 1.]
# 238 [0. 1. 0.]
# 239 [0. 1. 0.]
# 240 [0. 0. 1.]
# 241 [1. 0. 0.]
# 242 [0. 1. 0.]
# 243 [1. 0. 0.]
# 244 [1. 0. 0.]
# 245 [1. 0. 0.]
# 246 [1. 0. 0.]
# 247 [1. 0. 0.]
# 248 [0. 0. 1.]
# 249 [0. 0. 1.]
# 250 [1. 0. 0.]

# %%
fig = plt.figure(figsize = (15, 5))
plt.plot(df['Close'], color='r', lw=2.)
plt.plot(df['Close'], '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(df['Close'], 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('TWTR total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()

# %%
from datetime import datetime

volume = df['Volume'].tolist()

for i in range(100):
    print(agent.trade([real_trend[i], volume[i]]))
# Out:
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.255190'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.255190'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.263349'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.265301'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.268331'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.268882'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.268882'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.268882'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.269919'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.270265'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.271305'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.271305'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.271973'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.273695'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.274711'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.274963'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.274963'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.276001'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.276203'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.281094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.281094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.281094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.281094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.281094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.281094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.281094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.281094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.296845'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.296845'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.296845'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.296845'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.296845'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2022-07-29 12:22:47.296845'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 43.869999', 'action': 'buy', 'balance': 49.649997000000006, 'timestamp': '2022-07-29 12:22:47.296845'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 49.649997000000006, 'timestamp': '2022-07-29 12:22:47.296845'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 44.490002', 'action': 'buy', 'balance': 5.159995000000009, 'timestamp': '2022-07-29 12:22:47.296845'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 44.259998', 'investment': 0.8889879391153009, 'gain': 0.3899990000000031, 'balance': 49.41999300000001, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.312471'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 44.709999', 'investment': 0.4944863792094378, 'gain': 0.21999700000000644, 'balance': 94.12999200000002, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.312471'}
# [1.00000000e+000 5.82891236e-315 0.00000000e+000]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 94.12999200000002, 'timestamp': '2022-07-29 12:22:47.312471'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 94.12999200000002, 'timestamp': '2022-07-29 12:22:47.312471'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 43.419998', 'action': 'buy', 'balance': 50.709994000000016, 'timestamp': '2022-07-29 12:22:47.312471'}
# [8.91167399e-35 1.00000000e+00 0.00000000e+00]
# {'status': 'buy 1 unit, cost 43.310001', 'action': 'buy', 'balance': 7.399993000000016, 'timestamp': '2022-07-29 12:22:47.312471'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 42.169998', 'investment': -2.878857801881981, 'gain': -1.25, 'balance': 49.569991000000016, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.328094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 49.569991000000016, 'timestamp': '2022-07-29 12:22:47.328094'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 42.939999', 'action': 'buy', 'balance': 6.629992000000016, 'timestamp': '2022-07-29 12:22:47.328094'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 34.119999', 'investment': -21.219122114543474, 'gain': -9.190002, 'balance': 40.749991000000016, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.328094'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 40.749991000000016, 'timestamp': '2022-07-29 12:22:47.328094'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 31.870001', 'action': 'buy', 'balance': 8.879990000000017, 'timestamp': '2022-07-29 12:22:47.328094'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 8.879990000000017, 'timestamp': '2022-07-29 12:22:47.343726'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 8.879990000000017, 'timestamp': '2022-07-29 12:22:47.343726'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 31.959999', 'investment': -25.570564172579513, 'gain': -10.98, 'balance': 40.83998900000002, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.343726'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 32.980000', 'investment': 3.482896031286584, 'gain': 1.1099989999999949, 'balance': 73.81998900000002, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.343726'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 32.669998', 'action': 'buy', 'balance': 41.14999100000002, 'timestamp': '2022-07-29 12:22:47.343726'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 31.840000', 'action': 'buy', 'balance': 9.309991000000021, 'timestamp': '2022-07-29 12:22:47.343726'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 9.309991000000021, 'timestamp': '2022-07-29 12:22:47.343726'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 9.309991000000021, 'timestamp': '2022-07-29 12:22:47.359521'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 32.799999', 'investment': 0.39792166500897863, 'gain': 0.13000100000000003, 'balance': 42.109990000000025, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.361556'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 33.189999', 'action': 'buy', 'balance': 8.919991000000024, 'timestamp': '2022-07-29 12:22:47.361556'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 32.380001', 'investment': 1.6959830402010057, 'gain': 0.5400010000000002, 'balance': 41.299992000000024, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.361556'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 32.830002', 'investment': -1.0846550492514322, 'gain': -0.3599969999999999, 'balance': 74.12999400000002, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.361556'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 32.730000', 'action': 'buy', 'balance': 41.39999400000003, 'timestamp': '2022-07-29 12:22:47.361556'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 32.599998', 'investment': -0.3971952337305149, 'gain': -0.1300019999999975, 'balance': 73.99999200000002, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.361556'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 33.689999', 'action': 'buy', 'balance': 40.30999300000002, 'timestamp': '2022-07-29 12:22:47.361556'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 33.810001', 'action': 'buy', 'balance': 6.49999200000002, 'timestamp': '2022-07-29 12:22:47.377281'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 33.880001', 'investment': 0.5639715216376224, 'gain': 0.19000199999999978, 'balance': 40.37999300000002, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.377281'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 34.279999', 'investment': 1.3901153093725043, 'gain': 0.4699979999999968, 'balance': 74.65999200000002, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.377281'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.377281'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.377281'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.377281'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.377281'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.377281'}
# [6.66674763e-70 0.00000000e+00 1.00000000e+00]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.392901'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.392901'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.392901'}
# [1.00000000e+000 6.19246706e-107 0.00000000e+000]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.392901'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 74.65999200000002, 'timestamp': '2022-07-29 12:22:47.392901'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 30.889999', 'action': 'buy', 'balance': 43.769993000000014, 'timestamp': '2022-07-29 12:22:47.392901'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 29.750000', 'investment': -3.690511611865056, 'gain': -1.1399989999999995, 'balance': 73.51999300000001, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.392901'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 73.51999300000001, 'timestamp': '2022-07-29 12:22:47.408520'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 30.120001', 'action': 'buy', 'balance': 43.39999200000001, 'timestamp': '2022-07-29 12:22:47.408520'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 43.39999200000001, 'timestamp': '2022-07-29 12:22:47.408520'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 29.219999', 'action': 'buy', 'balance': 14.17999300000001, 'timestamp': '2022-07-29 12:22:47.408520'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 14.17999300000001, 'timestamp': '2022-07-29 12:22:47.408520'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 29.850000', 'investment': -0.8964176329210399, 'gain': -0.2700009999999935, 'balance': 44.02999300000001, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.408520'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 28.500000', 'action': 'buy', 'balance': 15.529993000000012, 'timestamp': '2022-07-29 12:22:47.408520'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 28.600000', 'investment': -2.121831010329603, 'gain': -0.619999, 'balance': 44.12999300000001, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.408520'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 29.110001', 'investment': 2.140354385964914, 'gain': 0.6100010000000005, 'balance': 73.23999400000001, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.425757'}
# [0.00000000e+000 1.00000000e+000 2.22224416e-253]
# {'status': 'buy 1 unit, cost 29.010000', 'action': 'buy', 'balance': 44.229994000000005, 'timestamp': '2022-07-29 12:22:47.425757'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 29.420000', 'investment': 1.4133057566356557, 'gain': 0.4100000000000037, 'balance': 73.649994, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.425757'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 73.649994, 'timestamp': '2022-07-29 12:22:47.425757'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 28.309999', 'action': 'buy', 'balance': 45.339995, 'timestamp': '2022-07-29 12:22:47.425757'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 28.190001', 'investment': -0.4238714384977636, 'gain': -0.11999800000000249, 'balance': 73.529996, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.425757'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 73.529996, 'timestamp': '2022-07-29 12:22:47.425757'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 73.529996, 'timestamp': '2022-07-29 12:22:47.425757'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 73.529996, 'timestamp': '2022-07-29 12:22:47.441529'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 73.529996, 'timestamp': '2022-07-29 12:22:47.441529'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 73.529996, 'timestamp': '2022-07-29 12:22:47.441529'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 26.790001', 'action': 'buy', 'balance': 46.73999499999999, 'timestamp': '2022-07-29 12:22:47.441529'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 27.000000', 'action': 'buy', 'balance': 19.739994999999993, 'timestamp': '2022-07-29 12:22:47.441529'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 27.990000', 'investment': 4.479279414733858, 'gain': 1.1999989999999947, 'balance': 47.72999499999999, 'action': 'sell', 'timestamp': '2022-07-29 12:22:47.441529'}

# %%
import copy
import pickle

copy_model = copy.deepcopy(agent.model)

with open('model.pkl', 'wb') as fopen:
    pickle.dump(copy_model, fopen)
